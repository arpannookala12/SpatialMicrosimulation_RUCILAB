# %%
import os
import pandas as pd
import sqlite3

# Define the base directory where your HPSDATA folder is located
base_directory = 'D:\\Desktop_New\\RUCI_LAB\\HPSDATA'

# Define the name for the SQLite database (you can customize the naming methodology)
db_name = 'HPS_Phases_Data.db'  # Example naming convention
db_path = os.path.join("D:\\Desktop_New\\RUCI_LAB\\SpatialMicrosimulation_RUCILAB", db_name)

# Create or connect to an SQLite database
conn = sqlite3.connect(db_path)
cursor = conn.cursor()

# Iterate through each phase folder
for phase_folder in os.listdir(base_directory):
    phase_folder_path = os.path.join(base_directory, phase_folder)

    # Check if the path is a directory
    if os.path.isdir(phase_folder_path):
        # Iterate through each sub-folder within the phase folder
        for sub_folder in os.listdir(phase_folder_path):
            sub_folder_path = os.path.join(phase_folder_path, sub_folder)

            # Check if the path is a directory
            if os.path.isdir(sub_folder_path):
                # Iterate through each file in the sub-folder
                for file in os.listdir(sub_folder_path):
                    # Check if the file contains 'puf' but not 'repwgt'
                    if 'puf' in file.lower() and 'repwgt' not in file.lower():
                        file_path = os.path.join(sub_folder_path, file)
                        
                        # Read the CSV file into a pandas DataFrame
                        try:
                            df = pd.read_csv(file_path)
                            
                            # Clean the table name to be safe for SQLite
                            table_name = f"{phase_folder}_{sub_folder}_{os.path.splitext(file)[0]}"
                            table_name = table_name.replace("-", "_").replace(".", "_").replace(" ", "_")
                            
                            # Store the data in the SQLite database
                            df.to_sql(table_name, conn, if_exists='replace', index=False)
                            
                            print(f"Loaded data from {file} into table '{table_name}'.")
                        except Exception as e:
                            print(f"Error processing {file_path}: {e}")

# Close the database connection
conn.close()

print(f"Database saved at: {db_path}")
# Out:
# Loaded data from pulse2020_puf_13.csv into table 'Phase_2_HPS_Week13_PUF_CSV(August19_August31)2020_pulse2020_puf_13'.
# Loaded data from pulse2020_puf_14.csv into table 'Phase_2_HPS_Week14_PUF_CSV(September2_September14)2020_pulse2020_puf_14'.
# Loaded data from pulse2020_puf_15.csv into table 'Phase_2_HPS_Week15_PUF_CSV(September16_September28)2020_pulse2020_puf_15'.
# Loaded data from pulse2020_puf_16.csv into table 'Phase_2_HPS_Week16_PUF_CSV(September30_October12)2020_pulse2020_puf_16'.
# Loaded data from pulse2020_puf_17.csv into table 'Phase_2_HPS_Week17_PUF_CSV(October14_October26)2020_pulse2020_puf_17'.
# Loaded data from pulse2020_puf_18.csv into table 'Phase_3_HPS_Week18_PUF_CSV(October28_November9)2020_pulse2020_puf_18'.
# Loaded data from pulse2020_puf_19.csv into table 'Phase_3_HPS_Week19_PUF_CSV(November11_November23)2020_pulse2020_puf_19'.
# Loaded data from pulse2020_puf_20.csv into table 'Phase_3_HPS_Week20_PUF_CSV(November25_December7)2020_pulse2020_puf_20'.
# Loaded data from pulse2020_puf_21.csv into table 'Phase_3_HPS_Week21_PUF_CSV(December9_December21)2020_pulse2020_puf_21'.
# Loaded data from pulse2021_puf_22.csv into table 'Phase_3_HPS_Week22_PUF_CSV(January6_January18)2021_pulse2021_puf_22'.
# Loaded data from pulse2021_puf_23.csv into table 'Phase_3_HPS_Week23_PUF_CSV(January20_February1)2021_pulse2021_puf_23'.
# Loaded data from pulse2021_puf_24.csv into table 'Phase_3_HPS_Week24_PUF_CSV(February3_February15)2021_pulse2021_puf_24'.
# Loaded data from pulse2021_puf_25.csv into table 'Phase_3_HPS_Week25_PUF_CSV(February17_March1)2021_pulse2021_puf_25'.
# Loaded data from pulse2021_puf_26.csv into table 'Phase_3_HPS_Week26_PUF_CSV(March3_March15)2021_pulse2021_puf_26'.
# Loaded data from pulse2021_puf_27.csv into table 'Phase_3_HPS_Week27_PUF_CSV(March17_March29)2021_pulse2021_puf_27'.
# Loaded data from pulse2021_puf_28.csv into table 'Phase_3_1_HPS_Week28_PUF_CSV(April14_April26)2021_pulse2021_puf_28'.
# Loaded data from pulse2021_puf_29.csv into table 'Phase_3_1_HPS_Week29_PUF_CSV(April28_May10)2021_pulse2021_puf_29'.
# Loaded data from pulse2021_puf_30.csv into table 'Phase_3_1_HPS_Week30_PUF_CSV(May12_May24)2021_pulse2021_puf_30'.
# Loaded data from pulse2021_puf_31.csv into table 'Phase_3_1_HPS_Week31_PUF_CSV(May26_June7)2021_pulse2021_puf_31'.
# Loaded data from pulse2021_puf_32.csv into table 'Phase_3_1_HPS_Week32_PUF_CSV(June9_June21)2021_pulse2021_puf_32'.
# Loaded data from pulse2021_puf_33.csv into table 'Phase_3_1_HPS_Week33_PUF_CSV(June23_July5)2021_pulse2021_puf_33'.
# Loaded data from pulse2023_puf_61.csv into table 'Phase_3_10_HPS_Week61_PUF_CSV(August23_September4)2023_pulse2023_puf_61'.
# Loaded data from pulse2023_puf_62.csv into table 'Phase_3_10_HPS_Week62_PUF_CSV(September20_October2)2023_pulse2023_puf_62'.
# Loaded data from pulse2023_puf_63.csv into table 'Phase_3_10_HPS_Week63_PUF_CSV(October18_October30)2023_pulse2023_puf_63'.
# Loaded data from pulse2021_puf_34.csv into table 'Phase_3_2_HPS_Week34_PUF_CSV(July21_August2)2021_pulse2021_puf_34'.
# Loaded data from pulse2021_puf_35.csv into table 'Phase_3_2_HPS_Week35_PUF_CSV(August4_August16)2021_pulse2021_puf_35'.
# Loaded data from pulse2021_puf_36.csv into table 'Phase_3_2_HPS_Week36_PUF_CSV(August18_August30)2021_pulse2021_puf_36'.
# Loaded data from pulse2021_puf_37.csv into table 'Phase_3_2_HPS_Week37_PUF_CSV(September1_September13)2021_pulse2021_puf_37'.
# Loaded data from pulse2021_puf_38.csv into table 'Phase_3_2_HPS_Week38_PUF_CSV(September15_September27)2021_pulse2021_puf_38'.
# Loaded data from pulse2021_puf_39.csv into table 'Phase_3_2_HPS_Week39_PUF_CSV(September29_October11)2021_pulse2021_puf_39'.
# Loaded data from pulse2021_puf_40.csv into table 'Phase_3_3_HPS_Week40_PUF_CSV(December1_December13)2021_pulse2021_puf_40'.
# Loaded data from pulse2022_puf_41.csv into table 'Phase_3_3_HPS_Week41_PUF_CSV(December29_2021_January10_2022)_pulse2022_puf_41'.
# Loaded data from pulse2022_puf_42.csv into table 'Phase_3_3_HPS_Week42_PUF_CSV(January26_February7)2022_pulse2022_puf_42'.
# Loaded data from pulse2022_puf_43.csv into table 'Phase_3_4_HPS_Week43_PUF_CSV(March2_March14)2022_pulse2022_puf_43'.
# Loaded data from pulse2022_puf_44.csv into table 'Phase_3_4_HPS_Week44_PUF_CSV(March30_April11)2022_pulse2022_puf_44'.
# Loaded data from pulse2022_puf_45.csv into table 'Phase_3_4_HPS_Week45_PUF_CSV(April27_May9)2022_pulse2022_puf_45'.
# Loaded data from pulse2022_puf_46.csv into table 'Phase_3_5_HPS_Week46_PUF_CSV(June1_June13)2022_pulse2022_puf_46'.
# Loaded data from pulse2022_puf_47.csv into table 'Phase_3_5_HPS_Week47_PUF_CSV(June29_July11)2022_pulse2022_puf_47'.
# Loaded data from pulse2022_puf_48.csv into table 'Phase_3_5_HPS_Week48_PUF_CSV(July27_August8)2022_pulse2022_puf_48'.
# Loaded data from pulse2022_puf_49.csv into table 'Phase_3_6_HPS_Week49_PUF_CSV(September14_September28)2022_pulse2022_puf_49'.
# Loaded data from pulse2022_puf_50.csv into table 'Phase_3_6_HPS_Week50_PUF_CSV(October5_October17)2022_pulse2022_puf_50'.
# Loaded data from pulse2022_puf_51.csv into table 'Phase_3_6_HPS_Week51_PUF_CSV(November2_November14)2022_pulse2022_puf_51'.
# Loaded data from pulse2022_puf_52.csv into table 'Phase_3_7_HPS_Week52_PUF_CSV(December9_December19)2022_pulse2022_puf_52'.
# Loaded data from pulse2023_puf_53.csv into table 'Phase_3_7_HPS_Week53_PUF_CSV(January4_January16)2023_pulse2023_puf_53'.
# Loaded data from pulse2023_puf_54.csv into table 'Phase_3_7_HPS_Week54_PUF_CSV(February1_February13)2023_pulse2023_puf_54'.
# Loaded data from pulse2023_puf_55.csv into table 'Phase_3_8_HPS_Week55_PUF_CSV(March1_March13)2023_pulse2023_puf_55'.
# Loaded data from pulse2023_puf_56.csv into table 'Phase_3_8_HPS_Week56_PUF_CSV(March_29_April10)2023_pulse2023_puf_56'.
# Loaded data from pulse2023_puf_57.csv into table 'Phase_3_8_HPS_Week57_PUF_CSV(April26_May8)2023_pulse2023_puf_57'.
# Loaded data from pulse2023_puf_58.csv into table 'Phase_3_9_HPS_Week58_PUF_CSV(June7_June19)2023_pulse2023_puf_58'.
# Loaded data from pulse2023_puf_59.csv into table 'Phase_3_9_HPS_Week59_PUF_CSV(June28_July10)2023_pulse2023_puf_59'.
# Loaded data from pulse2023_puf_60.csv into table 'Phase_3_9_HPS_Week60_PUF_CSV(July26_August7)2023_pulse2023_puf_60'.
# Loaded data from hps_04_00_01_puf.csv into table 'Phase_4_0_HPS_Phase4Cycle01_PUF_CSV(January9_February5)2024_hps_04_00_01_puf'.
# Loaded data from hps_04_00_02_puf.csv into table 'Phase_4_0_HPS_Phase4Cycle02_PUF_CSV(February6_March4)2024_hps_04_00_02_puf'.
# Loaded data from hps_04_00_03_puf.csv into table 'Phase_4_0_HPS_Phase4Cycle03_PUF_CSV(March5_April1)2024_hps_04_00_03_puf'.
# Loaded data from hps_04_01_04_puf.csv into table 'Phase_4_1_HPS_Phase4_1Cycle04_PUF_CSV(April2_April29)2024_hps_04_01_04_puf'.
# Loaded data from hps_04_01_05_puf.csv into table 'Phase_4_1_HPS_Phase4_1Cycle05_PUF_CSV(April30_May27)2024_hps_04_01_05_puf'.
# Loaded data from hps_04_01_06_puf.csv into table 'Phase_4_1_HPS_Phase4_1Cycle06_PUF_CSV(May28_June24)2024_hps_04_01_06_puf'.
# Loaded data from hps_04_01_07_puf.csv into table 'Phase_4_1_HPS_Phase4_1Cycle07_PUF_CSV(June25_July22)2024_hps_04_01_07_puf'.
# Loaded data from hps_04_02_08_puf.csv into table 'Phase_4_2_HPS_Phase4_2Cycle08_PUF_CSV(July23_August19)2024_hps_04_02_08_puf'.
# Loaded data from hps_04_02_09_puf.csv into table 'Phase_4_2_HPS_Phase4_2Cycle09_PUF_CSV(Aug20_Sep16)2024_hps_04_02_09_puf'.
# Database saved at: D:\Desktop_New\RUCI_LAB\SpatialMicrosimulation_RUCILAB\HPS_Phases_Data.db
